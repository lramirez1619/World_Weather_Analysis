# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a coordinates 
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city) 
    
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
! dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is DED1-55ED
#
#  Directory of C:\Users\lesta\Desktop\Module 6\Challenge\Weather_Database
#
# 12/23/2022  10:04 AM    <DIR>          .
# 12/23/2022  10:04 AM    <DIR>          ..
# 12/22/2022  09:38 AM    <DIR>          .ipynb_checkpoints
# 12/22/2022  11:05 AM                52 config.py
# 12/22/2022  09:21 AM         7,944,447 Vacation_Itinerary_starter_code.ipynb
# 12/22/2022  09:21 AM            24,435 WeatherPy_vacation-backup.csv
# 12/23/2022  10:04 AM           200,422 Weather_Database.ipynb
# 12/22/2022  11:05 AM    <DIR>          __pycache__
#                4 File(s)      8,169,356 bytes
#                4 Dir(s)  155,158,556,672 bytes free

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=89987763daca6d4688a82f7a8500a2ad

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
       
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]['description']
        
    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather description": city_weather_desc})
                                 
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | soyo
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | taltal
# Processing Record 5 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 6 of Set 1 | zhigansk
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | rensvik
# Processing Record 9 of Set 1 | deputatskiy
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | vao
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | narsaq
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | khani
# Processing Record 21 of Set 1 | hobart
# Processing Record 22 of Set 1 | nargana
# Processing Record 23 of Set 1 | airai
# Processing Record 24 of Set 1 | victoria
# Processing Record 25 of Set 1 | benxi
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | ayabaca
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | saint-pierre
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | carmen
# Processing Record 33 of Set 1 | arteaga
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | hami
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | nyurba
# Processing Record 38 of Set 1 | clyde river
# Processing Record 39 of Set 1 | fryanovo
# Processing Record 40 of Set 1 | lompoc
# Processing Record 41 of Set 1 | chapais
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | vardo
# Processing Record 44 of Set 1 | ust-ordynskiy
# Processing Record 45 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | torbay
# Processing Record 48 of Set 1 | yeppoon
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | lagos
# Processing Record 7 of Set 2 | roald
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | constitucion
# Processing Record 11 of Set 2 | inhambane
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | madang
# Processing Record 14 of Set 2 | barrow
# Processing Record 15 of Set 2 | goderich
# Processing Record 16 of Set 2 | ostrov
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | lafiagi
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | neiafu
# Processing Record 22 of Set 2 | cedar city
# Processing Record 23 of Set 2 | sao filipe
# Processing Record 24 of Set 2 | crateus
# Processing Record 25 of Set 2 | ketchikan
# Processing Record 26 of Set 2 | tsuruoka
# Processing Record 27 of Set 2 | talcahuano
# Processing Record 28 of Set 2 | bousso
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | provideniya
# Processing Record 31 of Set 2 | ivangorod
# Processing Record 32 of Set 2 | alofi
# Processing Record 33 of Set 2 | mezen
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | isangel
# Processing Record 36 of Set 2 | yulara
# Processing Record 37 of Set 2 | totoro
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | hithadhoo
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | jamestown
# Processing Record 43 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 44 of Set 2 | kristiinankaupunki
# Processing Record 45 of Set 2 | mount gambier
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | tinde
# Processing Record 48 of Set 2 | laguna
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | togur
# Processing Record 3 of Set 3 | la ronge
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | ancud
# Processing Record 6 of Set 3 | tomatlan
# Processing Record 7 of Set 3 | aklavik
# Processing Record 8 of Set 3 | bulgan
# Processing Record 9 of Set 3 | saint-philippe
# Processing Record 10 of Set 3 | berbera
# Processing Record 11 of Set 3 | hasaki
# Processing Record 12 of Set 3 | kurumkan
# Processing Record 13 of Set 3 | poum
# Processing Record 14 of Set 3 | bahia blanca
# Processing Record 15 of Set 3 | katsuura
# Processing Record 16 of Set 3 | naberera
# Processing Record 17 of Set 3 | buluang
# Processing Record 18 of Set 3 | alyangula
# Processing Record 19 of Set 3 | tallahassee
# Processing Record 20 of Set 3 | perivolion
# Processing Record 21 of Set 3 | kommunar
# Processing Record 22 of Set 3 | namanyere
# Processing Record 23 of Set 3 | komsomolskiy
# Processing Record 24 of Set 3 | champerico
# Processing Record 25 of Set 3 | rockland
# Processing Record 26 of Set 3 | huarmey
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | meulaboh
# Processing Record 29 of Set 3 | panzhihua
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | hun
# Processing Record 33 of Set 3 | erenhot
# Processing Record 34 of Set 3 | voznesenye
# Processing Record 35 of Set 3 | yumen
# Processing Record 36 of Set 3 | kaeo
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 3 | port augusta
# Processing Record 40 of Set 3 | dubai
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | cabinda
# Processing Record 43 of Set 3 | nome
# Processing Record 44 of Set 3 | banda aceh
# Processing Record 45 of Set 3 | anklam
# Processing Record 46 of Set 3 | bambous virieux
# Processing Record 47 of Set 3 | salina cruz
# Processing Record 48 of Set 3 | birjand
# Processing Record 49 of Set 3 | campos gerais
# Processing Record 50 of Set 3 | saldanha
# Processing Record 1 of Set 4 | buala
# Processing Record 2 of Set 4 | tarquinia
# Processing Record 3 of Set 4 | georgetown
# Processing Record 4 of Set 4 | kruisfontein
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | isla mujeres
# Processing Record 7 of Set 4 | juba
# Processing Record 8 of Set 4 | oyama
# Processing Record 9 of Set 4 | porbandar
# Processing Record 10 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 11 of Set 4 | san cristobal
# Processing Record 12 of Set 4 | kandava
# Processing Record 13 of Set 4 | ust-koksa
# Processing Record 14 of Set 4 | lauria
# Processing Record 15 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 4 | yerbogachen
# Processing Record 17 of Set 4 | yellowknife
# Processing Record 18 of Set 4 | thompson
# Processing Record 19 of Set 4 | digby
# Processing Record 20 of Set 4 | burica
# City not found. Skipping...
# Processing Record 21 of Set 4 | udimskiy
# Processing Record 22 of Set 4 | beipiao
# Processing Record 23 of Set 4 | khandbari
# Processing Record 24 of Set 4 | kurilsk
# Processing Record 25 of Set 4 | beitbridge
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | farnworth
# Processing Record 28 of Set 4 | fiumicino
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | cam ranh
# Processing Record 32 of Set 4 | ucluelet
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 4 | millville
# Processing Record 35 of Set 4 | bayan
# Processing Record 36 of Set 4 | baykit
# Processing Record 37 of Set 4 | broome
# Processing Record 38 of Set 4 | esna
# Processing Record 39 of Set 4 | somerset
# Processing Record 40 of Set 4 | lopatino
# Processing Record 41 of Set 4 | margate
# Processing Record 42 of Set 4 | cap malheureux
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | sisophon
# Processing Record 45 of Set 4 | san quintin
# Processing Record 46 of Set 4 | ureki
# Processing Record 47 of Set 4 | jacareacanga
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | palembang
# Processing Record 1 of Set 5 | korla
# Processing Record 2 of Set 5 | tadine
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | kholtoson
# Processing Record 5 of Set 5 | ardistan
# City not found. Skipping...
# Processing Record 6 of Set 5 | faanui
# Processing Record 7 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 5 | tiruchchendur
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 5 | ishigaki
# Processing Record 12 of Set 5 | thabazimbi
# Processing Record 13 of Set 5 | crotone
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | lastoursville
# Processing Record 16 of Set 5 | farah
# Processing Record 17 of Set 5 | aykhal
# Processing Record 18 of Set 5 | arman
# Processing Record 19 of Set 5 | upernavik
# Processing Record 20 of Set 5 | santa engracia
# Processing Record 21 of Set 5 | esperance
# Processing Record 22 of Set 5 | vanimo
# Processing Record 23 of Set 5 | bethel
# Processing Record 24 of Set 5 | austin
# Processing Record 25 of Set 5 | shikhany
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | chikwawa
# Processing Record 30 of Set 5 | lerwick
# Processing Record 31 of Set 5 | moramanga
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | rocha
# Processing Record 34 of Set 5 | tarauaca
# Processing Record 35 of Set 5 | husavik
# Processing Record 36 of Set 5 | norsup
# Processing Record 37 of Set 5 | kutum
# Processing Record 38 of Set 5 | savannah bight
# Processing Record 39 of Set 5 | tessalit
# Processing Record 40 of Set 5 | robertsport
# Processing Record 41 of Set 5 | kavieng
# Processing Record 42 of Set 5 | targusor
# Processing Record 43 of Set 5 | asau
# Processing Record 44 of Set 5 | sitka
# Processing Record 45 of Set 5 | aizpute
# Processing Record 46 of Set 5 | abu samrah
# Processing Record 47 of Set 5 | bathsheba
# Processing Record 48 of Set 5 | ampanihy
# Processing Record 49 of Set 5 | palmer
# Processing Record 50 of Set 5 | mount isa
# Processing Record 1 of Set 6 | mocuba
# Processing Record 2 of Set 6 | dwarka
# Processing Record 3 of Set 6 | frontera
# Processing Record 4 of Set 6 | coquimbo
# Processing Record 5 of Set 6 | amboasary
# Processing Record 6 of Set 6 | limoeiro do ajuru
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 9 of Set 6 | dawson creek
# Processing Record 10 of Set 6 | kodiak
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | ramgarh
# Processing Record 13 of Set 6 | mehamn
# Processing Record 14 of Set 6 | maghama
# City not found. Skipping...
# Processing Record 15 of Set 6 | kieta
# Processing Record 16 of Set 6 | cherskiy
# Processing Record 17 of Set 6 | talnakh
# Processing Record 18 of Set 6 | brody
# Processing Record 19 of Set 6 | raudeberg
# Processing Record 20 of Set 6 | luebo
# Processing Record 21 of Set 6 | dinguiraye
# Processing Record 22 of Set 6 | darhan
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | diego de almagro
# Processing Record 25 of Set 6 | wanning
# Processing Record 26 of Set 6 | bengkulu
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | gimli
# Processing Record 29 of Set 6 | tuy hoa
# Processing Record 30 of Set 6 | verkhnevilyuysk
# Processing Record 31 of Set 6 | tarko-sale
# Processing Record 32 of Set 6 | sapatgram
# Processing Record 33 of Set 6 | fairbanks
# Processing Record 34 of Set 6 | yar-sale
# Processing Record 35 of Set 6 | hualmay
# Processing Record 36 of Set 6 | laiyang
# Processing Record 37 of Set 6 | zachagansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 39 of Set 6 | komatipoort
# Processing Record 40 of Set 6 | ossora
# Processing Record 41 of Set 6 | emba
# Processing Record 42 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | kavaratti
# Processing Record 44 of Set 6 | teknaf
# Processing Record 45 of Set 6 | jumla
# Processing Record 46 of Set 6 | haines junction
# Processing Record 47 of Set 6 | hamilton
# Processing Record 48 of Set 6 | lavrentiya
# Processing Record 49 of Set 6 | loknya
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | necochea
# Processing Record 2 of Set 7 | rio gallegos
# Processing Record 3 of Set 7 | srednekolymsk
# Processing Record 4 of Set 7 | pauini
# Processing Record 5 of Set 7 | mitu
# Processing Record 6 of Set 7 | dedougou
# Processing Record 7 of Set 7 | praia da vitoria
# Processing Record 8 of Set 7 | zabaykalsk
# Processing Record 9 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 7 | porto nacional
# Processing Record 11 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 7 | iqaluit
# Processing Record 14 of Set 7 | camopi
# Processing Record 15 of Set 7 | krasnoselkup
# Processing Record 16 of Set 7 | buta
# Processing Record 17 of Set 7 | salekhard
# Processing Record 18 of Set 7 | tahta
# Processing Record 19 of Set 7 | magistralnyy
# Processing Record 20 of Set 7 | gamba
# Processing Record 21 of Set 7 | klamath falls
# Processing Record 22 of Set 7 | changde
# Processing Record 23 of Set 7 | saint-leu
# Processing Record 24 of Set 7 | pasighat
# Processing Record 25 of Set 7 | salinopolis
# Processing Record 26 of Set 7 | boquira
# Processing Record 27 of Set 7 | robe
# Processing Record 28 of Set 7 | vrangel
# Processing Record 29 of Set 7 | namibe
# Processing Record 30 of Set 7 | fare
# Processing Record 31 of Set 7 | kemlya
# Processing Record 32 of Set 7 | okhotsk
# Processing Record 33 of Set 7 | ust-kut
# Processing Record 34 of Set 7 | moron
# Processing Record 35 of Set 7 | mlonggo
# Processing Record 36 of Set 7 | laramie
# Processing Record 37 of Set 7 | pangkalanbuun
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | charters towers
# Processing Record 40 of Set 7 | hare bay
# Processing Record 41 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 7 | aldan
# Processing Record 43 of Set 7 | taoudenni
# Processing Record 44 of Set 7 | pinega
# Processing Record 45 of Set 7 | crossville
# Processing Record 46 of Set 7 | touros
# Processing Record 47 of Set 7 | usinsk
# Processing Record 48 of Set 7 | nishihara
# Processing Record 49 of Set 7 | tilichiki
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 1 of Set 8 | sabzevar
# Processing Record 2 of Set 8 | fort nelson
# Processing Record 3 of Set 8 | daulatpur
# Processing Record 4 of Set 8 | tamsweg
# Processing Record 5 of Set 8 | erzin
# Processing Record 6 of Set 8 | whitianga
# Processing Record 7 of Set 8 | labuhan
# Processing Record 8 of Set 8 | carnarvon
# Processing Record 9 of Set 8 | nelson bay
# Processing Record 10 of Set 8 | presidencia roque saenz pena
# Processing Record 11 of Set 8 | erdenet
# Processing Record 12 of Set 8 | itoman
# Processing Record 13 of Set 8 | loei
# Processing Record 14 of Set 8 | rawson
# Processing Record 15 of Set 8 | loandjili
# Processing Record 16 of Set 8 | innisfail
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | marsh harbour
# Processing Record 19 of Set 8 | russell
# Processing Record 20 of Set 8 | mwene-ditu
# Processing Record 21 of Set 8 | sao jose da coroa grande
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | bismil
# Processing Record 24 of Set 8 | lasa
# Processing Record 25 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 8 | demirci
# Processing Record 27 of Set 8 | ostrovnoy
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | sibu
# Processing Record 30 of Set 8 | eskisehir
# Processing Record 31 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 8 | klaksvik
# Processing Record 33 of Set 8 | souris
# Processing Record 34 of Set 8 | adrar
# Processing Record 35 of Set 8 | beringovskiy
# Processing Record 36 of Set 8 | mulanje
# Processing Record 37 of Set 8 | ambon
# Processing Record 38 of Set 8 | aasiaat
# Processing Record 39 of Set 8 | moshupa
# Processing Record 40 of Set 8 | codrington
# Processing Record 41 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 8 | takoradi
# Processing Record 43 of Set 8 | palmas
# Processing Record 44 of Set 8 | nandyal
# Processing Record 45 of Set 8 | corning
# Processing Record 46 of Set 8 | salto de pirapora
# Processing Record 47 of Set 8 | suzu
# City not found. Skipping...
# Processing Record 48 of Set 8 | lakatoro
# Processing Record 49 of Set 8 | andenes
# Processing Record 50 of Set 8 | himora
# City not found. Skipping...
# Processing Record 1 of Set 9 | eyl
# Processing Record 2 of Set 9 | ranfurly
# Processing Record 3 of Set 9 | novopokrovka
# Processing Record 4 of Set 9 | san rafael
# Processing Record 5 of Set 9 | waspan
# Processing Record 6 of Set 9 | corn island
# Processing Record 7 of Set 9 | mundra
# Processing Record 8 of Set 9 | tukrah
# Processing Record 9 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 9 | tambilil
# Processing Record 11 of Set 9 | salalah
# Processing Record 12 of Set 9 | pathein
# Processing Record 13 of Set 9 | bushehr
# Processing Record 14 of Set 9 | corrales
# Processing Record 15 of Set 9 | sola
# Processing Record 16 of Set 9 | ambulu
# Processing Record 17 of Set 9 | lubbock
# Processing Record 18 of Set 9 | nanortalik
# Processing Record 19 of Set 9 | andarab
# City not found. Skipping...
# Processing Record 20 of Set 9 | malmesbury
# Processing Record 21 of Set 9 | tuatapere
# Processing Record 22 of Set 9 | tambura
# Processing Record 23 of Set 9 | khagaria
# Processing Record 24 of Set 9 | shingu
# Processing Record 25 of Set 9 | miandrivazo
# Processing Record 26 of Set 9 | half moon bay
# Processing Record 27 of Set 9 | timbiqui
# Processing Record 28 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 29 of Set 9 | ternate
# Processing Record 30 of Set 9 | probistip
# Processing Record 31 of Set 9 | aswan
# Processing Record 32 of Set 9 | te anau
# Processing Record 33 of Set 9 | araouane
# Processing Record 34 of Set 9 | banamba
# Processing Record 35 of Set 9 | alice springs
# Processing Record 36 of Set 9 | qeshm
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | sulangan
# Processing Record 39 of Set 9 | uvinza
# Processing Record 40 of Set 9 | asayita
# City not found. Skipping...
# Processing Record 41 of Set 9 | antibes
# Processing Record 42 of Set 9 | san patricio
# Processing Record 43 of Set 9 | dargaville
# Processing Record 44 of Set 9 | iranshahr
# Processing Record 45 of Set 9 | barabash
# Processing Record 46 of Set 9 | acari
# Processing Record 47 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 48 of Set 9 | avera
# Processing Record 49 of Set 9 | karema
# Processing Record 50 of Set 9 | svetlogorsk
# Processing Record 1 of Set 10 | alugan
# Processing Record 2 of Set 10 | kinablangan
# Processing Record 3 of Set 10 | malinyi
# Processing Record 4 of Set 10 | shache
# Processing Record 5 of Set 10 | nuuk
# Processing Record 6 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 10 | marrakesh
# Processing Record 8 of Set 10 | zhob
# Processing Record 9 of Set 10 | norman wells
# Processing Record 10 of Set 10 | hofn
# Processing Record 11 of Set 10 | ursulo galvan
# Processing Record 12 of Set 10 | lahij
# Processing Record 13 of Set 10 | kirakira
# Processing Record 14 of Set 10 | portland
# Processing Record 15 of Set 10 | yasothon
# Processing Record 16 of Set 10 | oranjestad
# Processing Record 17 of Set 10 | kalianget
# Processing Record 18 of Set 10 | vredendal
# Processing Record 19 of Set 10 | brecksville
# Processing Record 20 of Set 10 | pringsewu
# Processing Record 21 of Set 10 | kimbe
# Processing Record 22 of Set 10 | yatou
# Processing Record 23 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 10 | qaqortoq
# Processing Record 25 of Set 10 | vanino
# Processing Record 26 of Set 10 | cururupu
# Processing Record 27 of Set 10 | mayo
# Processing Record 28 of Set 10 | daru
# Processing Record 29 of Set 10 | kawalu
# Processing Record 30 of Set 10 | behshahr
# Processing Record 31 of Set 10 | san marcos
# Processing Record 32 of Set 10 | saint-joseph
# Processing Record 33 of Set 10 | jaisinghnagar
# Processing Record 34 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 10 | wawa
# Processing Record 36 of Set 10 | ussel
# Processing Record 37 of Set 10 | iwade
# Processing Record 38 of Set 10 | la union
# Processing Record 39 of Set 10 | betare oya
# Processing Record 40 of Set 10 | tricase
# Processing Record 41 of Set 10 | barcelos
# Processing Record 42 of Set 10 | caconda
# Processing Record 43 of Set 10 | gweta
# Processing Record 44 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 10 | nizhniy kuranakh
# Processing Record 46 of Set 10 | zapolyarnyy
# Processing Record 47 of Set 10 | tiarei
# Processing Record 48 of Set 10 | ati
# Processing Record 49 of Set 10 | sandwich
# Processing Record 50 of Set 10 | miri
# Processing Record 1 of Set 11 | hastings
# Processing Record 2 of Set 11 | aginskoye
# Processing Record 3 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 4 of Set 11 | davila
# Processing Record 5 of Set 11 | cayenne
# Processing Record 6 of Set 11 | namatanai
# Processing Record 7 of Set 11 | sechura
# Processing Record 8 of Set 11 | srivardhan
# Processing Record 9 of Set 11 | llata
# Processing Record 10 of Set 11 | ahipara
# Processing Record 11 of Set 11 | north bend
# Processing Record 12 of Set 11 | bera
# Processing Record 13 of Set 11 | trinidad
# Processing Record 14 of Set 11 | kumano
# Processing Record 15 of Set 11 | kuytun
# Processing Record 16 of Set 11 | maragogi
# Processing Record 17 of Set 11 | pokaran
# Processing Record 18 of Set 11 | honningsvag
# Processing Record 19 of Set 11 | kassala
# Processing Record 20 of Set 11 | cheremukhovo
# Processing Record 21 of Set 11 | tezu
# Processing Record 22 of Set 11 | port keats
# Processing Record 23 of Set 11 | kalmunai
# Processing Record 24 of Set 11 | ormara
# Processing Record 25 of Set 11 | saint-francois
# Processing Record 26 of Set 11 | brewster
# Processing Record 27 of Set 11 | kidal
# Processing Record 28 of Set 11 | auki
# Processing Record 29 of Set 11 | semporna
# Processing Record 30 of Set 11 | nago
# Processing Record 31 of Set 11 | ulundurpettai
# City not found. Skipping...
# Processing Record 32 of Set 11 | zhanaozen
# Processing Record 33 of Set 11 | merauke
# Processing Record 34 of Set 11 | gushikawa
# Processing Record 35 of Set 11 | ilulissat
# Processing Record 36 of Set 11 | bend
# Processing Record 37 of Set 11 | conceicao do mato dentro
# Processing Record 38 of Set 11 | pochutla
# Processing Record 39 of Set 11 | luqiao
# Processing Record 40 of Set 11 | caravelas
# Processing Record 41 of Set 11 | kasli
# Processing Record 42 of Set 11 | sirjan
# Processing Record 43 of Set 11 | lodja
# Processing Record 44 of Set 11 | bowling green
# Processing Record 45 of Set 11 | saint anthony
# Processing Record 46 of Set 11 | zheleznodorozhnyy
# Processing Record 47 of Set 11 | ilirska bistrica
# Processing Record 48 of Set 11 | atambua
# Processing Record 49 of Set 11 | oktyabrskoye
# Processing Record 50 of Set 11 | tevaitoa
# Processing Record 1 of Set 12 | itarema
# Processing Record 2 of Set 12 | price
# Processing Record 3 of Set 12 | kenai
# Processing Record 4 of Set 12 | coria
# Processing Record 5 of Set 12 | aranda de duero
# Processing Record 6 of Set 12 | wuchi
# Processing Record 7 of Set 12 | turinsk
# Processing Record 8 of Set 12 | juneau
# Processing Record 9 of Set 12 | maldonado
# Processing Record 10 of Set 12 | chegdomyn
# Processing Record 11 of Set 12 | copiapo
# Processing Record 12 of Set 12 | gazanjyk
# Processing Record 13 of Set 12 | lagoa
# Processing Record 14 of Set 12 | hobyo
# Processing Record 15 of Set 12 | iralaya
# Processing Record 16 of Set 12 | rudbar
# Processing Record 17 of Set 12 | kemi
# Processing Record 18 of Set 12 | sao joao da barra
# Processing Record 19 of Set 12 | ambilobe
# Processing Record 20 of Set 12 | tual
# Processing Record 21 of Set 12 | baiquan
# Processing Record 22 of Set 12 | whitehorse
# Processing Record 23 of Set 12 | ndjole
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | de aar
# Processing Record 26 of Set 12 | rovaniemi
# Processing Record 27 of Set 12 | koboldo
# City not found. Skipping...
# Processing Record 28 of Set 12 | college
# Processing Record 29 of Set 12 | san policarpo
# Processing Record 30 of Set 12 | karratha
# Processing Record 31 of Set 12 | cockburn town
# Processing Record 32 of Set 12 | ondangwa
# Processing Record 33 of Set 12 | lisala
# Processing Record 34 of Set 12 | zhuhai
# Processing Record 35 of Set 12 | bonnyville
# Processing Record 36 of Set 12 | igarka
# Processing Record 37 of Set 12 | ismailia
# Processing Record 38 of Set 12 | hajnowka
# Processing Record 39 of Set 12 | westport
# Processing Record 40 of Set 12 | erzurum
# Processing Record 41 of Set 12 | espinosa
# Processing Record 42 of Set 12 | belmonte
# Processing Record 43 of Set 12 | bodden town
# Processing Record 44 of Set 12 | tura
# Processing Record 45 of Set 12 | bilibino
# Processing Record 46 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 12 | marystown
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | casablanca
# Processing Record 50 of Set 12 | miracema do tocantins
# Processing Record 1 of Set 13 | urusha
# Processing Record 2 of Set 13 | plettenberg bay
# Processing Record 3 of Set 13 | burnie
# Processing Record 4 of Set 13 | matamoros
# Processing Record 5 of Set 13 | imari
# Processing Record 6 of Set 13 | port macquarie
# Processing Record 7 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 13 | acapulco
# Processing Record 9 of Set 13 | dehloran
# Processing Record 10 of Set 13 | nushki
# Processing Record 11 of Set 13 | quelimane
# Processing Record 12 of Set 13 | belyy
# Processing Record 13 of Set 13 | oussouye
# Processing Record 14 of Set 13 | preobrazheniye
# Processing Record 15 of Set 13 | caxias
# Processing Record 16 of Set 13 | clocolan
# Processing Record 17 of Set 13 | nawabshah
# Processing Record 18 of Set 13 | lucea
# Processing Record 19 of Set 13 | armilla
# Processing Record 20 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 13 | sioux lookout
# Processing Record 22 of Set 13 | bandarbeyla
# Processing Record 23 of Set 13 | jian
# Processing Record 24 of Set 13 | akdepe
# Processing Record 25 of Set 13 | elizabethton
# Processing Record 26 of Set 13 | krylovskaya
# Processing Record 27 of Set 13 | menongue
# Processing Record 28 of Set 13 | coihaique
# Processing Record 29 of Set 13 | sampit
# Processing Record 30 of Set 13 | bowen
# Processing Record 31 of Set 13 | port hardy
# Processing Record 32 of Set 13 | labytnangi
# Processing Record 33 of Set 13 | harper
# Processing Record 34 of Set 13 | vidalia
# Processing Record 35 of Set 13 | atar
# Processing Record 36 of Set 13 | egvekinot
# Processing Record 37 of Set 13 | gari
# Processing Record 38 of Set 13 | sur
# Processing Record 39 of Set 13 | ivajlovgrad
# City not found. Skipping...
# Processing Record 40 of Set 13 | golspie
# Processing Record 41 of Set 13 | kannur
# Processing Record 42 of Set 13 | santa cruz
# Processing Record 43 of Set 13 | tocopilla
# Processing Record 44 of Set 13 | togitsu
# Processing Record 45 of Set 13 | bezhanitsy
# Processing Record 46 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | pangai
# Processing Record 48 of Set 13 | pandan
# Processing Record 49 of Set 13 | capissayan
# Processing Record 50 of Set 13 | maniitsoq
# Processing Record 1 of Set 14 | grindavik
# Processing Record 2 of Set 14 | shubarkuduk
# Processing Record 3 of Set 14 | murbad
# Processing Record 4 of Set 14 | los llanos de aridane
# Processing Record 5 of Set 14 | nosy varika
# Processing Record 6 of Set 14 | penzance
# Processing Record 7 of Set 14 | lungi
# Processing Record 8 of Set 14 | baoqing
# Processing Record 9 of Set 14 | plouzane
# Processing Record 10 of Set 14 | puerto escondido
# Processing Record 11 of Set 14 | faratsiho
# Processing Record 12 of Set 14 | gura teghii
# Processing Record 13 of Set 14 | turbat
# Processing Record 14 of Set 14 | shitanjing
# Processing Record 15 of Set 14 | vila do maio
# Processing Record 16 of Set 14 | gravdal
# Processing Record 17 of Set 14 | sept-iles
# Processing Record 18 of Set 14 | puerto madryn
# Processing Record 19 of Set 14 | niteroi
# Processing Record 20 of Set 14 | las vegas
# Processing Record 21 of Set 14 | requena
# Processing Record 22 of Set 14 | teguldet
# Processing Record 23 of Set 14 | mangrol
# Processing Record 24 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 14 | chake chake
# Processing Record 26 of Set 14 | dalbandin
# Processing Record 27 of Set 14 | palu
# Processing Record 28 of Set 14 | tall kayf
# Processing Record 29 of Set 14 | tongzi
# Processing Record 30 of Set 14 | abonnema
# Processing Record 31 of Set 14 | springfield
# Processing Record 32 of Set 14 | kolobrzeg
# Processing Record 33 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 14 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 14 | kholm-zhirkovskiy
# Processing Record 36 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 37 of Set 14 | bullhead city
# Processing Record 38 of Set 14 | taonan
# Processing Record 39 of Set 14 | south lake tahoe
# Processing Record 40 of Set 14 | ankang
# Processing Record 41 of Set 14 | brigantine
# Processing Record 42 of Set 14 | sahrak
# City not found. Skipping...
# Processing Record 43 of Set 14 | owando
# Processing Record 44 of Set 14 | alihe
# Processing Record 45 of Set 14 | dinan
# Processing Record 46 of Set 14 | verkhoyansk
# Processing Record 47 of Set 14 | yabrud
# Processing Record 48 of Set 14 | rio grande
# Processing Record 49 of Set 14 | narok
# Processing Record 50 of Set 14 | meiganga
# Processing Record 1 of Set 15 | nchelenge
# Processing Record 2 of Set 15 | kajaani
# Processing Record 3 of Set 15 | pontal do parana
# Processing Record 4 of Set 15 | peniche
# Processing Record 5 of Set 15 | nabire
# Processing Record 6 of Set 15 | pontes e lacerda
# Processing Record 7 of Set 15 | catabola
# Processing Record 8 of Set 15 | kudahuvadhoo
# Processing Record 9 of Set 15 | ekhabi
# Processing Record 10 of Set 15 | ahmadpur east
# Processing Record 11 of Set 15 | la macarena
# Processing Record 12 of Set 15 | sicamous
# Processing Record 13 of Set 15 | phnum penh
# City not found. Skipping...
# Processing Record 14 of Set 15 | muros
# Processing Record 15 of Set 15 | tecoman
# Processing Record 16 of Set 15 | troitskoye
# Processing Record 17 of Set 15 | mujiayingzi
# Processing Record 18 of Set 15 | poli
# Processing Record 19 of Set 15 | kununurra
# Processing Record 20 of Set 15 | great falls
# Processing Record 21 of Set 15 | morro bay
# Processing Record 22 of Set 15 | coromandel
# Processing Record 23 of Set 15 | saint-augustin
# Processing Record 24 of Set 15 | ruteng
# Processing Record 25 of Set 15 | paranaiba
# Processing Record 26 of Set 15 | diu
# Processing Record 27 of Set 15 | arlit
# Processing Record 28 of Set 15 | luwingu
# Processing Record 29 of Set 15 | urucara
# Processing Record 30 of Set 15 | grimshaw
# Processing Record 31 of Set 15 | mnogovershinnyy
# Processing Record 32 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 15 | antofagasta
# Processing Record 34 of Set 15 | dakar
# Processing Record 35 of Set 15 | marawi
# Processing Record 36 of Set 15 | pias
# Processing Record 37 of Set 15 | zyryanka
# Processing Record 38 of Set 15 | churapcha
# Processing Record 39 of Set 15 | hailun
# Processing Record 40 of Set 15 | muhos
# Processing Record 41 of Set 15 | camacha
# Processing Record 42 of Set 15 | peskovka
# Processing Record 43 of Set 15 | pimentel
# Processing Record 44 of Set 15 | ust-maya
# Processing Record 45 of Set 15 | camana
# Processing Record 46 of Set 15 | jalu
# Processing Record 47 of Set 15 | pacific grove
# Processing Record 48 of Set 15 | valerianovsk
# Processing Record 49 of Set 15 | zharkent
# Processing Record 50 of Set 15 | honiara
# Processing Record 1 of Set 16 | hvammstangi
# City not found. Skipping...
# Processing Record 2 of Set 16 | lamu
# Processing Record 3 of Set 16 | inirida
# Processing Record 4 of Set 16 | port hedland
# Processing Record 5 of Set 16 | havelock
# Processing Record 6 of Set 16 | manaure
# Processing Record 7 of Set 16 | mantua
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
print(city_data)
# Out:
# [{'City': 'Soyo', 'Lat': -6.1349, 'Lng': 12.3689, 'Max Temp': 80.53, 'Humidity': 72, 'Cloudiness': 86, 'Wind Speed': 7.87, 'Country': 'AO', 'Weather description': 'overcast clouds'}, {'City': 'Naze', 'Lat': 28.3667, 'Lng': 129.4833, 'Max Temp': 51.26, 'Humidity': 72, 'Cloudiness': 99, 'Wind Speed': 23.67, 'Country': 'JP', 'Weather description': 'light rain'}, {'City': 'Taltal', 'Lat': -25.4, 'Lng': -70.4833, 'Max Temp': 68.49, 'Humidity': 74, 'Cloudiness': 30, 'Wind Speed': 5.44, 'Country': 'CL', 'Weather description': 'scattered clouds'}, {'City': 'Zhigansk', 'Lat': 66.7697, 'Lng': 123.3711, 'Max Temp': -18.42, 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 3.62, 'Country': 'RU', 'Weather description': 'overcast clouds'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 77.14, 'Humidity': 74, 'Cloudiness': 100, 'Wind Speed': 11.56, 'Country': 'PF', 'Weather description': 'overcast clouds'}, {'City': 'Rensvik', 'Lat': 63.1, 'Lng': 7.8167, 'Max Temp': 32.27, 'Humidity': 80, 'Cloudiness': 75, 'Wind Speed': 9.22, 'Country': 'NO', 'Weather description': 'light snow'}, {'City': 'Deputatskiy', 'Lat': 69.3, 'Lng': 139.9, 'Max Temp': -23.66, 'Humidity': 88, 'Cloudiness': 4, 'Wind Speed': 5.01, 'Country': 'RU', 'Weather description': 'clear sky'}, {'City': 'Punta Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 51.12, 'Humidity': 40, 'Cloudiness': 37, 'Wind Speed': 27.4, 'Country': 'CL', 'Weather description': 'scattered clouds'}, {'City': 'Port Alfred', 'Lat': -33.5906, 'Lng': 26.891, 'Max Temp': 69.19, 'Humidity': 84, 'Cloudiness': 100, 'Wind Speed': 5.01, 'Country': 'ZA', 'Weather description': 'moderate rain'}, {'City': 'Dikson', 'Lat': 73.5069, 'Lng': 80.5464, 'Max Temp': -1.3, 'Humidity': 87, 'Cloudiness': 100, 'Wind Speed': 28.05, 'Country': 'RU', 'Weather description': 'overcast clouds'}, {'City': 'Mar Del Plata', 'Lat': -38.0023, 'Lng': -57.5575, 'Max Temp': 83.82, 'Humidity': 78, 'Cloudiness': 40, 'Wind Speed': 17, 'Country': 'AR', 'Weather description': 'scattered clouds'}, {'City': 'Atuona', 'Lat': -9.8, 'Lng': -139.0333, 'Max Temp': 77.88, 'Humidity': 76, 'Cloudiness': 57, 'Wind Speed': 16.82, 'Country': 'PF', 'Weather description': 'broken clouds'}, {'City': 'Vao', 'Lat': -22.6667, 'Lng': 167.4833, 'Max Temp': 78.57, 'Humidity': 80, 'Cloudiness': 35, 'Wind Speed': 8.25, 'Country': 'NC', 'Weather description': 'scattered clouds'}, {'City': 'Ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 46.02, 'Humidity': 77, 'Cloudiness': 92, 'Wind Speed': 21.68, 'Country': 'AR', 'Weather description': 'overcast clouds'}, {'City': 'Port Elizabeth', 'Lat': -33.918, 'Lng': 25.5701, 'Max Temp': 67.32, 'Humidity': 95, 'Cloudiness': 93, 'Wind Speed': 8.01, 'Country': 'ZA', 'Weather description': 'moderate rain'}, {'City': 'Narsaq', 'Lat': 60.9167, 'Lng': -46.05, 'Max Temp': 12.42, 'Humidity': 65, 'Cloudiness': 0, 'Wind Speed': 7.78, 'Country': 'GL', 'Weather description': 'clear sky'}, {'City': 'Fortuna', 'Lat': 40.5982, 'Lng': -124.1573, 'Max Temp': 57.92, 'Humidity': 88, 'Cloudiness': 100, 'Wind Speed': 12.66, 'Country': 'US', 'Weather description': 'overcast clouds'}, {'City': 'Khani', 'Lat': 41.9563, 'Lng': 42.9566, 'Max Temp': 44.17, 'Humidity': 57, 'Cloudiness': 0, 'Wind Speed': 5.59, 'Country': 'GE', 'Weather description': 'clear sky'}, {'City': 'Hobart', 'Lat': -42.8794, 'Lng': 147.3294, 'Max Temp': 60.66, 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 8.05, 'Country': 'AU', 'Weather description': 'overcast clouds'}, {'City': 'Nargana', 'Lat': 9.4428, 'Lng': -78.5906, 'Max Temp': 82.33, 'Humidity': 77, 'Cloudiness': 82, 'Wind Speed': 12.75, 'Country': 'PA', 'Weather description': 'broken clouds'}, {'City': 'Airai', 'Lat': -8.9266, 'Lng': 125.4092, 'Max Temp': 61.61, 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 1.54, 'Country': 'TL', 'Weather description': 'overcast clouds'}, {'City': 'Victoria', 'Lat': 22.2855, 'Lng': 114.1577, 'Max Temp': 63.25, 'Humidity': 46, 'Cloudiness': 14, 'Wind Speed': 5.01, 'Co ...

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Soyo  -6.1349   12.3689     80.53        72          86
# 1          Naze  28.3667  129.4833     51.26        72          99
# 2        Taltal -25.4000  -70.4833     68.49        74          30
# 3      Zhigansk  66.7697  123.3711    -18.42        92         100
# 4       Rikitea -23.1203 -134.9692     77.14        74         100
# 5       Rensvik  63.1000    7.8167     32.27        80          75
# 6   Deputatskiy  69.3000  139.9000    -23.66        88           4
# 7  Punta Arenas -53.1500  -70.9167     51.12        40          37
# 8   Port Alfred -33.5906   26.8910     69.19        84         100
# 9        Dikson  73.5069   80.5464     -1.30        87         100
#
#    Wind Speed Country Weather description
# 0        7.87      AO     overcast clouds
# 1       23.67      JP          light rain
# 2        5.44      CL    scattered clouds
# 3        3.62      RU     overcast clouds
# 4       11.56      PF     overcast clouds
# 5        9.22      NO          light snow
# 6        5.01      RU           clear sky
# 7       27.40      CL    scattered clouds
# 8        5.01      ZA       moderate rain
# 9       28.05      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather description"]

# Recreate the DataFrame by using the new column order
new_df = city_data_df[new_column_order]


# Display sample data
new_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Soyo      AO  -6.1349   12.3689     80.53        72          86
# 1          Naze      JP  28.3667  129.4833     51.26        72          99
# 2        Taltal      CL -25.4000  -70.4833     68.49        74          30
# 3      Zhigansk      RU  66.7697  123.3711    -18.42        92         100
# 4       Rikitea      PF -23.1203 -134.9692     77.14        74         100
# 5       Rensvik      NO  63.1000    7.8167     32.27        80          75
# 6   Deputatskiy      RU  69.3000  139.9000    -23.66        88           4
# 7  Punta Arenas      CL -53.1500  -70.9167     51.12        40          37
# 8   Port Alfred      ZA -33.5906   26.8910     69.19        84         100
# 9        Dikson      RU  73.5069   80.5464     -1.30        87         100
#
#    Wind Speed Weather description
# 0        7.87     overcast clouds
# 1       23.67          light rain
# 2        5.44    scattered clouds
# 3        3.62     overcast clouds
# 4       11.56     overcast clouds
# 5        9.22          light snow
# 6        5.01           clear sky
# 7       27.40    scattered clouds
# 8        5.01       moderate rain
# 9       28.05     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
new_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
